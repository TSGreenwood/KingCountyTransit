# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/My Drive/  # Navigate to the directory where you want to clone your repo
# !git clone https://github.com/TSGreenwood/KingCountyTransit.git
# Out:
# Mounted at /content/drive
# [Errno 2] No such file or directory: '/content/drive/My Drive/ # Navigate to the directory where you want to clone your repo'
# /content
# Cloning into 'KingCountyTransit'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (5/5), done.

# %%
# !pwd
# Out:
# /content
