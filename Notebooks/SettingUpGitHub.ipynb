# %%
# !git config --global user.name "TSGreenwood"
# !git config --global user.email "greenwood.ts@gmail.com"

# %%
# %cd /content/drive/MyDrive/KingCountyTransit
# Out:
# /content/drive/MyDrive/KingCountyTransit

# %%
# !git remote add origin https://github.com/TSGreenwood/KingCountyTransit.git
# Out:
# error: remote origin already exists.
